# %%
import pandas as pd

data = pd.read_csv('spam.csv', index_col = 0)

# %%
data_spam = data[data['label']=='spam']
data_ham = data[data['label']=='ham']

display(data_spam, data_ham)
# Out:
#                                                     text label
# 1            [Web발신]박춘규회원님손절주식은그만월급배만드는법http://lco.jp/eA  spam
# 2       [Web발신]골든브릿지에서손실을보셨나요??http://bitly.kr/bRGtq[FW]  spam
# 3                       [Web발신][대//박]가(.원)입코(WN)드MEP.com  spam
# 4      [Web발신](광고)이정미님아직도주식하시나요http://pf.kakao.com/_u...  spam
# 5           [Web발신]송승용님사람이모이는곳에는이유가있습니다하루~정보공개is.gd/JsJP  spam
# ...                                                  ...   ...
# 20090         [Web발신]회원님예치금원보유중보관기간이끝납니다쿠아리움.com<<다운로드코드  spam
# 20096  [Web발신]이상투자황기봉님"이재훈"투자컨설담당자배정완료.담당자확인▼http://b...  spam
# 20097        [Web발신](광고)조마?峙???충?矛?%:까지　↓주소Joma.카JM톡무료거부  spam
# 20098  [Web발신]김환택님지금이라도늦지않았습니다.월긴급정보http://pf.kakao.c...  spam
# 20100       [Web발신]최현님월일특급정보!https://pf.kakao.com/_SfcsT  spam
#
# [12817 rows x 2 columns]
#                                                     text label
# 6                                            MMS스팸신고사진사진   ham
# ...

# %%
data_spam = data[data['label']=='spam']
data_ham = data[data['label']=='ham']
data_spam = data_spam.reset_index(drop = True)
data_ham = data_ham.reset_index(drop = True)
a = []

for i in range (data_spam.shape[0]):
    a.append(len(data_spam['text'][i]))
    data_spam['len_spam'] = a
display(a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\lak50\Desktop\Untitled-1.ipynb 셀 3 in <cell line: 7>()
#       <a href='vscode-notebook-cell:/c%3A/Users/lak50/Desktop/Untitled-1.ipynb#W2sZmlsZQ%3D%3D?line=6'>7</a> for i in range (data_spam.shape[0]):
#       <a href='vscode-notebook-cell:/c%3A/Users/lak50/Desktop/Untitled-1.ipynb#W2sZmlsZQ%3D%3D?line=7'>8</a>     a.append(len(data_spam['text'][i]))
# ----> <a href='vscode-notebook-cell:/c%3A/Users/lak50/Desktop/Untitled-1.ipynb#W2sZmlsZQ%3D%3D?line=8'>9</a>     data_spam['len_spam'] = a
#      <a href='vscode-notebook-cell:/c%3A/Users/lak50/Desktop/Untitled-1.ipynb#W2sZmlsZQ%3D%3D?line=9'>10</a> display(a)
#
# File c:\Users\lak50\anaconda3\lib\site-packages\pandas\core\frame.py:3655, in DataFrame.__setitem__(self, key, value)
#    3652     self._setitem_array([key], value)
#    3653 else:
#    3654     # set column
# ...
