# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.datasets import mnist

(x_train, t_train), (x_test, t_test) = mnist.load_data()

print('\n train shape = ', x_train.shape, 
      ', train label shape = ', t_train.shape)
print(' test shape = ', x_test.shape, 
      ', test label shape =', t_test.shape)

print('\n train label = ', t_train)  # 학습데이터 정답 출력
print(' test label  = ', t_test)     # 테스트 데이터 정답 출력
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 1s 0us/step
#
#  train shape =  (60000, 28, 28) , train label shape =  (60000,)
#  test shape =  (10000, 28, 28) , test label shape = (10000,)
#
#  train label =  [5 0 4 ... 5 6 8]
#  test label  =  [7 2 1 ... 4 5 6]

# %%
import matplotlib.pyplot as plt

# 25개의 이미지 출력
plt.figure(figsize=(6, 6)) 

for index in range(25):    # 25 개 이미지 출력

    plt.subplot(5, 5, index + 1)  # 5행 5열 
    plt.imshow(x_train[index], cmap='gray') 
    plt.axis('off')   
    # plt.title(str(t_train[index]))

plt.show()

# %%
plt.imshow(x_train[9], cmap='gray') 
plt.colorbar()   
plt.show()

# %%
plt.title('train label distribution')
plt.grid()
plt.xlabel('label')

plt.hist(t_train, bins=10, rwidth=0.8)

plt.show()

# %%
# 학습데이터 정답 분포 확인

label_distribution = np.zeros(10)

for idx in range(len(t_train)):

    label = int(t_train[idx])

    label_distribution[label] = label_distribution[label] + 1


print(label_distribution)
# Out:
# [5923. 6742. 5958. 6131. 5842. 5421. 5918. 6265. 5851. 5949.]

# %%
# 학습 데이터 / 테스트 데이터 정규화 (Normalization)

x_train = (x_train - 0.0) / (255.0 - 0.0)

x_test = (x_test - 0.0) / (255.0 - 0.0)


# 정답 데이터 원핫 인코딩 (One-Hot Encoding)

t_train = tf.keras.utils.to_categorical(t_train, num_classes=10)

t_test = tf.keras.utils.to_categorical(t_test, num_classes=10)

# %%
model = tf.keras.Sequential()

model.add(tf.keras.layers.Flatten(input_shape=(28, 28)))

model.add(tf.keras.layers.Dense(100, activation='relu'))

model.add(tf.keras.layers.Dense(10, activation='softmax'))

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 100)               78500
#
#  dense_1 (Dense)             (None, 10)                1010
#
# =================================================================
# Total params: 79,510
# Trainable params: 79,510
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.fit(x_train, t_train, epochs=30, validation_split=0.3)
# Out:
# Epoch 1/30
# 1313/1313 [==============================] - 3s 2ms/step - loss: 0.3146 - accuracy: 0.9110 - val_loss: 0.1796 - val_accuracy: 0.9492
# Epoch 2/30
# 1313/1313 [==============================] - 2s 2ms/step - loss: 0.1436 - accuracy: 0.9576 - val_loss: 0.1447 - val_accuracy: 0.9572
# Epoch 3/30
# 1313/1313 [==============================] - 2s 2ms/step - loss: 0.1011 - accuracy: 0.9698 - val_loss: 0.1176 - val_accuracy: 0.9650
# Epoch 4/30
# 1313/1313 [==============================] - 2s 2ms/step - loss: 0.0780 - accuracy: 0.9767 - val_loss: 0.1103 - val_accuracy: 0.9683
# Epoch 5/30
# 1313/1313 [==============================] - 2s 2ms/step - loss: 0.0606 - accuracy: 0.9814 - val_loss: 0.1126 - val_accuracy: 0.9669
# Epoch 6/30
# 1313/1313 [==============================] - 2s 2ms/step - loss: 0.0475 - accuracy: 0.9855 - val_loss: 0.1105 - val_accuracy: 0.9678
# Epoch 7/30
# 1313/1313 [==============================] - 2s 2ms/step - loss: 0.0381 - accuracy: 0.9885 - val_loss: 0.1091 - val_accuracy: 0.9680
# Epoch 8/30
# 1313/1313 [==============================] - 2s 2ms/step - loss: 0.0312 - accuracy: 0.9911 - val_loss: 0.0984 - val_accuracy: 0.9717
# Epoch 9/30
# 1313/1313 [==============================] - 2s 2ms/step - loss: 0.0256 - accuracy: 0.9925 - val_loss: 0.0992 - val_accuracy: 0.9719
# Epoch 10/30
# 1313/1313 [==============================] - 2s 2ms/step - loss: 0.0214 - accuracy: 0.9936 - val_loss: 0.1139 - val_accuracy: 0.9685
# Epoch 11/30
# 1313/1313 [==============================] - 2s 2ms/step - loss: 0.0171 - accuracy: 0.9950 - val_loss: 0.1036 - val_accuracy: 0.9735
# Epoch 12/30
# 1313/1313 [==============================] - 2s 2ms/step - loss: 0.0149 - accuracy: 0.9955 - val_loss: 0.1120 - val_accuracy: 0.9726
# Epoch 13/30
# 1313/1313 [==============================] - 2s 2ms/step - loss: 0.0123 - accuracy: 0.9964 - val_loss: 0.1101 - val_accuracy: 0.9727
# Epoch 14/30
# 1313/1313 [==============================] - 2s 2ms/step - loss: 0.0092 - accuracy: 0.9980 - val_loss: 0.1173 - val_accuracy: 0.9713
# Epoch 15/30
# 1313/1313 [==============================] - 2s 2ms/step - loss: 0.0095 - accuracy: 0.9973 - val_loss: 0.1303 - val_accuracy: 0.9712
# Epoch 16/30
# 1313/1313 [==============================] - 2s 2ms/step - loss: 0.0081 - accuracy: 0.9979 - val_loss: 0.1259 - val_accuracy: 0.9716
# Epoch 17/30
# 1313/1313 [==============================] - 2s 2ms/step - loss: 0.0076 - accuracy: 0.9978 - val_loss: 0.1270 - val_accuracy: 0.9718
# Epoch 18/30
# 1313/1313 [==============================] - 2s 2ms/step - loss: 0.0073 - accuracy: 0.9979 - val_loss: 0.1176 - val_accuracy: 0.9748
# Epoch 19/30
# 1313/1313 [==============================] - 2s 2ms/step - loss: 0.0065 - accuracy: 0.9983 - val_loss: 0.1327 - val_accuracy: 0.9716
# Epoch 20/30
# 1313/1313 [==============================] - 2s 2ms/step - loss: 0.0048 - accuracy: 0.9988 - val_loss: 0.1388 - val_accuracy: 0.9698
# Epoch 21/30
# 1313/1313 [==============================] - 2s 2ms/step - loss: 0.0050 - accuracy: 0.9987 - val_loss: 0.1325 - val_accuracy: 0.9735
# Epoch 22/30
# 1313/1313 [==============================] - 2s 2ms/step - loss: 0.0055 - accuracy: 0.9981 - val_loss: 0.1406 - val_accuracy: 0.9721
# Epoch 23/30
# 1313/1313 [==============================] - 2s 2ms/step - loss: 0.0039 - accuracy: 0.9989 - val_loss: 0.1433 - val_accuracy: 0.9719
# Epoch 24/30
# 1313/1313 [==============================] - 2s 2ms/step - loss: 0.0047 - accuracy: 0.9985 - val_loss: 0.1563 - val_accuracy: 0.9711
# Epoch 25/30
# 1313/1313 [==============================] - 2s 2ms/step - loss: 0.0043 - accuracy: 0.9989 - val_loss: 0.1351 - val_accuracy: 0.9753
# Epoch 26/30
# 1313/1313 [==============================] - 2s 2ms/step - loss: 0.0030 - accuracy: 0.9993 - val_loss: 0.1538 - val_accuracy: 0.9722
# Epoch 27/30
# 1313/1313 [==============================] - 2s 2ms/step - loss: 0.0073 - accuracy: 0.9976 - val_loss: 0.1615 - val_accuracy: 0.9709
# Epoch 28/30
# 1313/1313 [==============================] - 2s 2ms/step - loss: 0.0019 - accuracy: 0.9996 - val_loss: 0.1372 - val_accuracy: 0.9751
# Epoch 29/30
# 1313/1313 [==============================] - 2s 2ms/step - loss: 4.1632e-04 - accuracy: 1.0000 - val_loss: 0.1390 - val_accuracy: 0.9746
# Epoch 30/30
# 1313/1313 [==============================] - 2s 2ms/step - loss: 0.0095 - accuracy: 0.9972 - val_loss: 0.1473 - val_accuracy: 0.9743

# %%
model.evaluate(x_test, t_test)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.1303 - accuracy: 0.9776
# [0.1303400695323944, 0.9775999784469604]

# %%
plt.title('Loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.grid()

plt.plot(hist.history['loss'], label='train loss')
plt.plot(hist.history['val_loss'], label='validation loss')

plt.legend(loc='best')

plt.show()

# %%
plt.title('Accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.grid()

plt.plot(hist.history['accuracy'], label='train accuracy')
plt.plot(hist.history['val_accuracy'], label='validation accuracy')

plt.legend(loc='best')

plt.show()

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

plt.figure(figsize=(6, 6))

predicted_value = model.predict(x_test)

cm = confusion_matrix(np.argmax(t_test, axis=-1),
                      np.argmax(predicted_value, axis=-1))

sns.heatmap(cm, annot=True, fmt='d')
plt.show()
# Out:
# 313/313 [==============================] - 0s 818us/step

# %%
print(cm)
print('\n')

for i in range(10):
    print(('label = %d\t(%d/%d)\taccuracy = %.3f') % 
          (i, np.max(cm[i]), np.sum(cm[i]), 
           np.max(cm[i])/np.sum(cm[i])))
# Out:
# [[ 973    0    2    1    0    1    1    0    1    1]
#  [   0 1124    2    1    0    0    2    1    5    0]
#  [   3    1 1006    3    2    1    3    7    6    0]
#  [   0    0    2  988    0    3    0    5    5    7]
#  [   1    0    1    1  962    1    5    2    2    7]
#  [   3    0    0   13    1  861    3    2    5    4]
#  [   6    2    0    1    7    3  937    0    1    1]
#  [   1    4    7    5    3    0    0  997    1   10]
#  [   6    0    1    2    7    5    4    5  941    3]
#  [   2    3    0    4    5    2    2    4    0  987]]
#
#
# label = 0	(973/980)	accuracy = 0.993
# label = 1	(1124/1135)	accuracy = 0.990
# label = 2	(1006/1032)	accuracy = 0.975
# label = 3	(988/1010)	accuracy = 0.978
# label = 4	(962/982)	accuracy = 0.980
# label = 5	(861/892)	accuracy = 0.965
# label = 6	(937/958)	accuracy = 0.978
# label = 7	(997/1028)	accuracy = 0.970
# label = 8	(941/974)	accuracy = 0.966
# label = 9	(987/1009)	accuracy = 0.978

# %%
# 정답 및 예측 값 분포 확인
label_distribution = np.zeros(10)
prediction_distribution = np.zeros(10)

for idx in range(len(t_test)):

    label = int(np.argmax(t_test[idx]))

    label_distribution[label] = label_distribution[label] + 1

    prediction = int(np.argmax(predicted_value[idx]))

    prediction_distribution[prediction] = prediction_distribution[prediction] + 1


print(label_distribution)
print(prediction_distribution)
# Out:
# [ 980. 1135. 1032. 1010.  982.  892.  958. 1028.  974. 1009.]
# [ 995. 1134. 1021. 1019.  987.  877.  957. 1023.  967. 1020.]
